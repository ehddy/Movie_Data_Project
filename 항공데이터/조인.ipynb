# %%
import pandas as pd

# %%
data = pd.read_excel('/Users/dongyokim/Downloads/ICAO.xlsx')

# %%
data2 = pd.read_excel('/Users/dongyokim/Downloads/11. 기종별 배출계수.xlsx')

# %%
data
# Out:
#        항공사     제조사       기종명  ICAO  좌석수  길이(m)  날개 폭(m)  높이(m)  최대운항거리(km)  \
# 0     대한항공  Boeing    B787-9  B789  269  62.80    60.10  17.00       12592
# 1     대한항공  Boeing    B787-9  B789  269  62.80    60.10  17.00       12592
# 2     대한항공  Boeing    B787-9  B789  269  62.80    60.10  17.00       12592
# 3     대한항공  Boeing    B787-9  B789  269  62.80    60.10  17.00       12592
# 4     대한항공  Boeing    B787-9  B789  269  62.80    60.10  17.00       12592
# ..     ...     ...       ...   ...  ...    ...      ...    ...         ...
# 184  플라이강원  Boeing  B737-800  B738  189  39.47    35.79  12.55        5452
# 185  플라이강원  Boeing  B737-800  B738  189  39.47    35.79  12.55        5452
# 186  플라이강원  Boeing  B737-800  B738  189  39.47    35.79  12.55        5452
# 187  플라이강원  Boeing  B737-800  B738  189  39.47    35.79  12.55        5452
# 188  플라이강원  Boeing  B737-800  B738  189  39.47    35.79  12.55        5452
#
#      순항속도(km/h) IATA type code(기종1)      Model(기종3)
# ...

# %%
data2
# Out:
#             ICAO      CO2    CH4   N2O  fuel Consumption (kg/LTO)  \
# 0           A300    5.470   1.00  0.20                       1.73
# 1           A310    4.900   0.40  0.20                       1.55
# 2           A320    2.560   0.04  0.10                     810.00
# 3        BAC1-11    2.150   6.80  0.10                     680.00
# 4       BAe  146    1.800   0.16  0.10                     570.00
# 5           B707    5.880   9.80  0.20                       1.86
# 6           B727    4.455   0.30  0.10                       1.41
# 7           B727    3.980   0.70  0.10                       1.26
# 8       B737-200    2.905   0.20  0.10                     920.00
# 9           B737    2.750   0.50  0.10                     870.00
# 10      B737-400    2.625   0.08  0.10                     830.00
# 11      B747-200   10.680   3.60  0.30                       3.38
# 12          B747   10.145   4.80  0.30                       3.21
# ...

# %%
total_data = pd.merge(data, data2, how='left', on='ICAO')

# %%
total_data.to_excel('조인 데이터셋(배출계수).xlsx')
