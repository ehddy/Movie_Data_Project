# %%
import pandas as pd 
from datetime import datetime

# %%
main_data = pd.read_excel('/Users/dongyokim/main/jupyter/2022:2/Movie_Project/데이터 전처리/영화 제목 및 정보 main_dataset_10_3.xlsx',index_col=0)

# %%
main_data
# Out:
#                   영화명           감독                              제작사  \
# 0                극한직업          이병헌   (주)어바웃잇,영화사 해그림 주식회사,(주)씨제이이엔엠
# 1          어벤져스: 엔드게임  안소니 루소,조 루소                              NaN
# 2              겨울왕국 2  크리스 벅,제니퍼 리                              NaN
# 3              범죄도시 2          이상용  주식회사 빅펀치픽쳐스,(주)홍필름,(주)비에이엔터테인먼트
# 4                 알라딘        가이 리치                              NaN
# ...               ...          ...                              ...
# 2860           종이 비행기       노홍식,필동                        (주)파란프로덕션
# 2861             보조바퀴          이주예                       주식회사 필름초이스
# 2862          엄마친구들 2          임현태                         (주)영화사가을
# 2863    스크림: 허수아비의 저주       루이자 워렌                              NaN
# 2864  일론 머스크: 리얼 아이언맨      소니아 앤더슨                              NaN
#
#                      수입사                            배급사        개봉일 영화형태  국적  \
# ...

# %%
naver_data = pd.read_excel('/Users/dongyokim/main/jupyter/2022:2/Movie_Project/크롤링/Naver_Movie_Rate_dataset.xlsx', index_col=0)

# %%
naver_data
# Out:
#                   영화명 네티즌, 관람객 평점 네티즌, 관람객 평점 참여자 기자, 평론가 평점 기자, 평론가 평점 참여자  \
# 0                극한직업        8.51          47,508       6.80             10
# 1          어벤져스: 엔드게임        9.38          69,265       7.62             13
# 2              겨울왕국 2        8.69          23,759       6.75              8
# 3              범죄도시 2        9.32          27,398       6.56              9
# 4                 알라딘        9.38          27,610       6.00              7
# ...               ...         ...             ...        ...            ...
# 2860           종이 비행기         NaN             NaN        NaN            NaN
# 2861             보조바퀴       10.00               6       6.00              1
# 2862          엄마친구들 2        4.25               4       0.00              0
# 2863    스크림: 허수아비의 저주         NaN             NaN        NaN            NaN
# 2864  일론 머스크: 리얼 아이언맨        5.15              20       0.00              0
#
# ...

# %%
# 영화명을 기준으로 병합
total_data = pd.concat([main_data, naver_data], axis=1)

# %%
# 현재 날짜 기준으로 저장
today_date = datetime.today().strftime("%Y_%m_%d") 

# 데이터를 원하는 형식으로 저장(csv일 경우 to_csv)
total_data.to_excel('영화데이터_네이버영화_병합_데이터{}.xlsx'.format(today_date))

# 폴더 안을 확인해보자
