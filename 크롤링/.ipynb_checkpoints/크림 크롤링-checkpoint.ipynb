# %%
from selenium import webdriver
import time
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup as bs
import pandas as pd

# %%
driver = webdriver.Chrome('/Users/dongyokim/main/jupyter/chromedriver/chromedriver')
driver.set_window_size(1000, 1000)
# Out:
# /var/folders/7d/bm3zqtjx7xsb__yxj254h7kh0000gn/T/ipykernel_95724/53075851.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('/Users/dongyokim/main/jupyter/chromedriver/chromedriver')

# %%
# 로그인 자동

driver.get('https://kream.co.kr/login')

# 네이버 id 
naver_id = ''
naver_pwd = ''

# 네이버로 로그인 클릭
naver_button = driver.find_element_by_css_selector('div.container.login > div.content.sm > div > div.social_login > button.btn.btn_login_naver.full.outline')
naver_button.click()
# Out:
# /var/folders/7d/bm3zqtjx7xsb__yxj254h7kh0000gn/T/ipykernel_95724/3519460490.py:6: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   naver_button = driver.find_element_by_css_selector('div.container.login > div.content.sm > div > div.social_login > button.btn.btn_login_naver.full.outline')

# %%
# Out:
# /var/folders/7d/bm3zqtjx7xsb__yxj254h7kh0000gn/T/ipykernel_95724/1527555438.py:14: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   brand_name = driver.find_element_by_css_selector('a.brand').text
# /var/folders/7d/bm3zqtjx7xsb__yxj254h7kh0000gn/T/ipykernel_95724/1527555438.py:21: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   eng_name = driver.find_element_by_css_selector('p.title').text
# /var/folders/7d/bm3zqtjx7xsb__yxj254h7kh0000gn/T/ipykernel_95724/1527555438.py:30: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   kor_name = driver.find_element_by_css_selector('p.sub_title').text
# /var/folders/7d/bm3zqtjx7xsb__yxj254h7kh0000gn/T/ipykernel_95724/1527555438.py:37: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ...

# %%
data = pd.DataFrame(data=total_list, columns=['브랜드명', '신발명(eng)', '신발명(kor)', '모델 코드','발매일', '발매가', '색상', '구매 가격', '판매 가격', '변동 가격(전달)'] )

# %%
data
